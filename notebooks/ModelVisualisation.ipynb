# %%
sys.path.append('../original/pytorch')
import torch
import hiddenlayer as hl
from model import Net

# %%
model = Net()

# Build HiddenLayer graph
# Jupyter Notebook renders it automatically
hl.build_graph(model, torch.zeros([1, 1, 768, 400]))
